# %% [markdown]
# <a href="https://colab.research.google.com/github/jeungsengho/python0610/blob/main/9_folium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. folium**

# %% [markdown]
# * 지도 위에 데이터를 표현해 주는 대표적인 파이썬 지도 시각화 라이브러리
# * leaflet.js 기반으로 만들어진 라이브러리
# * https://python-visualization.github.io/folium/

# %%
# !pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (0.8.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from folium) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from folium) (1.15.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->folium) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.10)

# %%
import folium

# %%
# folium.Map(location=[위도,경도], zoom_start=배율, ...)
map_folium = folium.Map(location=[37.511835, 127.038549], zoom_start=17)
# save() : 작성된 지도 차트를 html 파일로 저장
map_folium.save('./map.html')
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_d8634873be01ca140b5119498784c706 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_d8634873be01ca140b5119498784c706&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_d8634873be01ca140b5119498784c706 = L.map(
#         &#x27;map_d8634873be01ca140b5119498784c706&#x27;, {
#         center: [37.511835, 127.038549],
#         zoom: 17,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_27b38000e234f589436b099b153d3aba = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_d8634873be01ca140b5119498784c706);
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 스타일 (Open Street Map(기본값), Stamen Terrain, Stamen Toner)
map_folium = folium.Map(location=[37.511835, 127.038549], zoom_start=17, tiles='Open Street Map')
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_ffd3db84c170297a3f247f24547de08f {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_ffd3db84c170297a3f247f24547de08f&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_ffd3db84c170297a3f247f24547de08f = L.map(
#         &#x27;map_ffd3db84c170297a3f247f24547de08f&#x27;, {
#         center: [37.511835, 127.038549],
#         zoom: 17,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_6a7075b900b686d017875d22de647137 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_ffd3db84c170297a3f247f24547de08f);
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_folium = folium.Map(location=[37.511835, 127.038549], zoom_start=17, tiles='Stamen Terrain')
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_562a618f94b66c18e513b17a41d49c6b {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_562a618f94b66c18e513b17a41d49c6b&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_562a618f94b66c18e513b17a41d49c6b = L.map(
#         &#x27;map_562a618f94b66c18e513b17a41d49c6b&#x27;, {
#         center: [37.511835, 127.038549],
#         zoom: 17,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_04764126064a8ff627ada6fc32c8decc = L.tileLayer(
#         &#x27;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_562a618f94b66c18e513b17a41d49c6b);
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_folium = folium.Map(location=[37.511835, 127.038549], zoom_start=17, tiles='Stamen Toner')
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_97f37dbc7013287613744639b88e221a {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_97f37dbc7013287613744639b88e221a&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_97f37dbc7013287613744639b88e221a = L.map(
#         &#x27;map_97f37dbc7013287613744639b88e221a&#x27;, {
#         center: [37.511835, 127.038549],
#         zoom: 17,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_ed6ffcd6965b87b10b330bfb1fe7ed59 = L.tileLayer(
#         &#x27;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_97f37dbc7013287613744639b88e221a);
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=16)
# Marker() : location 속성으로 지정한 위치에 마커를 생성
# popup : 마커를 클릭했을 때 표시할 문자열을 설정
# add_to() : 작성된 마커를 지도에 추가
popup = folium.Popup('서울특별시청', max_width=200)
folium.Marker(location=[37.56652479270633, 126.9779129116262], popup=popup).add_to(map_folium)

popup = folium.Popup('덕수궁', max_width=200)
folium.Marker(location=[37.56585320879458, 126.97514572197248], popup=popup).add_to(map_folium)

popup = folium.Popup('서울지방경찰청', max_width=200)
folium.Marker(location=[37.57504045678939, 126.97195576938117], popup=popup).add_to(map_folium)

popup = folium.Popup('광화문', max_width=200)
folium.Marker(location=[37.57617987638928, 126.97694467807803], popup=popup).add_to(map_folium)

popup = folium.Popup('영풍문고-종로본점', max_width=200)
folium.Marker(location=[37.56999947440024, 126.98228391170936], popup=popup).add_to(map_folium)

map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_2c2cc33f1e915df2e4963b165ff33bc3 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_2c2cc33f1e915df2e4963b165ff33bc3&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_2c2cc33f1e915df2e4963b165ff33bc3 = L.map(
#         &#x27;map_2c2cc33f1e915df2e4963b165ff33bc3&#x27;, {
#         center: [37.56652479270633, 126.9779129116262],
#         zoom: 16,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_464dada9005f4c2adb45c8fe75292bcd = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_2c2cc33f1e915df2e4963b165ff33bc3);
#
#         var marker_e4a73a34b63729c3e0e20ebdaff91508 = L.marker(
#             [37.56652479270633, 126.9779129116262],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_2c2cc33f1e915df2e4963b165ff33bc3);
#
#
#             var popup_fd5361e8db51f3d2651c17167376ff5c = L.popup({maxWidth: &#x27;200&#x27;
#
#             });
#
#
#                 var html_1f8826322753df47eab1ea1e3d74db37 = $(`&lt;div id=&quot;html_1f8826322753df47eab1ea1e3d74db37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_fd5361e8db51f3d2651c17167376ff5c.setContent(html_1f8826322753df47eab1ea1e3d74db37);
#
#
#             marker_e4a73a34b63729c3e0e20ebdaff91508.bindPopup(popup_fd5361e8db51f3d2651c17167376ff5c)
#             ;
#
#
#
#
#         var marker_540cf6575c1b6e2bd5f9862568ae5453 = L.marker(
#             [37.56585320879458, 126.97514572197248],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_2c2cc33f1e915df2e4963b165ff33bc3);
#
#
#             var popup_7a45071af95104a740c5d7157d438342 = L.popup({maxWidth: &#x27;200&#x27;
#
#             });
#
#
#                 var html_0837a794639860e0f5a7029d2f6ddd3c = $(`&lt;div id=&quot;html_0837a794639860e0f5a7029d2f6ddd3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_7a45071af95104a740c5d7157d438342.setContent(html_0837a794639860e0f5a7029d2f6ddd3c);
#
#
#             marker_540cf6575c1b6e2bd5f9862568ae5453.bindPopup(popup_7a45071af95104a740c5d7157d438342)
#             ;
#
#
#
#
#         var marker_6e17f78c25c890d7c0e7858ca94e9a35 = L.marker(
#             [37.57504045678939, 126.97195576938117],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_2c2cc33f1e915df2e4963b165ff33bc3);
#
#
#             var popup_698f5e75edd7c027d2ce4ebc96161f10 = L.popup({maxWidth: &#x27;200&#x27;
#
#             });
#
#
#                 var html_669761e8b74d6402007e72cb6709652f = $(`&lt;div id=&quot;html_669761e8b74d6402007e72cb6709652f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울지방경찰청&lt;/div&gt;`)[0];
#                 popup_698f5e75edd7c027d2ce4ebc96161f10.setContent(html_669761e8b74d6402007e72cb6709652f);
#
#
#             marker_6e17f78c25c890d7c0e7858ca94e9a35.bindPopup(popup_698f5e75edd7c027d2ce4ebc96161f10)
#             ;
#
#
#
#
#         var marker_a03fe93446ccf6d6f35aa983feacdf00 = L.marker(
#             [37.57617987638928, 126.97694467807803],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_2c2cc33f1e915df2e4963b165ff33bc3);
#
#
#             var popup_2de5c53c94ccaa9cac61d41db59758ba = L.popup({maxWidth: &#x27;200&#x27;
#
#             });
#
#
#                 var html_7a440e98a9e88aaca895216de53790cf = $(`&lt;div id=&quot;html_7a440e98a9e88aaca895216de53790cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광화문&lt;/div&gt;`)[0];
#                 popup_2de5c53c94ccaa9cac61d41db59758ba.setContent(html_7a440e98a9e88aaca895216de53790cf);
#
#
#             marker_a03fe93446ccf6d6f35aa983feacdf00.bindPopup(popup_2de5c53c94ccaa9cac61d41db59758ba)
#             ;
#
#
#
#
#         var marker_77785d87182021998a1337896d9d4cdf = L.marker(
#             [37.56999947440024, 126.98228391170936],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_2c2cc33f1e915df2e4963b165ff33bc3);
#
#
#             var popup_3dd282ad1bf61c36282972ea65903f65 = L.popup({maxWidth: &#x27;200&#x27;
#
#             });
#
#
#                 var html_8df9439691f58eb4910ab0030f85b577 = $(`&lt;div id=&quot;html_8df9439691f58eb4910ab0030f85b577&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;영풍문고-종로본점&lt;/div&gt;`)[0];
#                 popup_3dd282ad1bf61c36282972ea65903f65.setContent(html_8df9439691f58eb4910ab0030f85b577);
#
#
#             marker_77785d87182021998a1337896d9d4cdf.bindPopup(popup_3dd282ad1bf61c36282972ea65903f65)
#             ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# icon() : 아이콘 모양을 설정
# https://getbootstrap.com/docs/3.3/components/#glyphicons-glyph

map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=16)

popup = folium.Popup('서울특별시청', max_width=200)
folium.Marker(location=[37.56652479270633, 126.9779129116262], popup=popup, icon=folium.Icon(color='green', icon='star')).add_to(map_folium)

popup = folium.Popup('덕수궁', max_width=200)
folium.Marker(location=[37.56585320879458, 126.97514572197248], popup=popup, icon=folium.Icon(color='red', icon='ok')).add_to(map_folium)

popup = folium.Popup('서울지방경찰청', max_width=200)
folium.Marker(location=[37.57504045678939, 126.97195576938117], popup=popup, icon=folium.Icon(color='blue', icon='user')).add_to(map_folium)

popup = folium.Popup('광화문', max_width=200)
folium.Marker(location=[37.57617987638928, 126.97694467807803], popup=popup, icon=folium.Icon(color='orange', icon='hand-down')).add_to(map_folium)

popup = folium.Popup('영풍문고-종로본점', max_width=200)
folium.Marker(location=[37.56999947440024, 126.98228391170936], popup=popup, icon=folium.Icon(color='purple', icon='eye-open')).add_to(map_folium)

map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_5da13c41ed701c1aa6b418631350fdb2 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_5da13c41ed701c1aa6b418631350fdb2&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_5da13c41ed701c1aa6b418631350fdb2 = L.map(
#         &#x27;map_5da13c41ed701c1aa6b418631350fdb2&#x27;, {
#         center: [37.56652479270633, 126.9779129116262],
#         zoom: 16,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_bf9678fa77750c342114a4cda1d89df4 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_5da13c41ed701c1aa6b418631350fdb2);
#
#         var marker_674473098620104082b69306dc1b347a = L.marker(
#             [37.56652479270633, 126.9779129116262],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5da13c41ed701c1aa6b418631350fdb2);
#
#
#
#                 var icon_d997bc427332f7f91b2af1830b31def7 = L.AwesomeMarkers.icon({
#                     icon: &#x27;star&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;green&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_674473098620104082b69306dc1b347a.setIcon(icon_d997bc427332f7f91b2af1830b31def7);
#
#
#             var popup_fbd3af9a0c43994152ae1deed4aac0c3 = L.popup({maxWidth: &#x27;200&#x27;
#
#             });
#
#
#                 var html_88fc6c4861a3b099bf125410f5afdc76 = $(`&lt;div id=&quot;html_88fc6c4861a3b099bf125410f5afdc76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_fbd3af9a0c43994152ae1deed4aac0c3.setContent(html_88fc6c4861a3b099bf125410f5afdc76);
#
#
#             marker_674473098620104082b69306dc1b347a.bindPopup(popup_fbd3af9a0c43994152ae1deed4aac0c3)
#             ;
#
#
#
#
#         var marker_884517e445c20a3c36434ee087aa8605 = L.marker(
#             [37.56585320879458, 126.97514572197248],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5da13c41ed701c1aa6b418631350fdb2);
#
#
#
#                 var icon_28dffb75f533a16f45e9d2749231a574 = L.AwesomeMarkers.icon({
#                     icon: &#x27;ok&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;red&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_884517e445c20a3c36434ee087aa8605.setIcon(icon_28dffb75f533a16f45e9d2749231a574);
#
#
#             var popup_f9a89f9fbbc3c514c2d6e2902f5e73a4 = L.popup({maxWidth: &#x27;200&#x27;
#
#             });
#
#
#                 var html_1a57c151536c1648ad74e8667aaffc32 = $(`&lt;div id=&quot;html_1a57c151536c1648ad74e8667aaffc32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_f9a89f9fbbc3c514c2d6e2902f5e73a4.setContent(html_1a57c151536c1648ad74e8667aaffc32);
#
#
#             marker_884517e445c20a3c36434ee087aa8605.bindPopup(popup_f9a89f9fbbc3c514c2d6e2902f5e73a4)
#             ;
#
#
#
#
#         var marker_a5e0e2f4e49d394cffc5861eec723605 = L.marker(
#             [37.57504045678939, 126.97195576938117],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5da13c41ed701c1aa6b418631350fdb2);
#
#
#
#                 var icon_99aa21c4a2a268e720db563a1c7f11c0 = L.AwesomeMarkers.icon({
#                     icon: &#x27;user&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;blue&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,
#                     extraClasses: &#x27;fa-rotate-0&#x27;
#                     });
#                 marker_a5e0e2f4e49d394cffc5861eec723605.setIcon(icon_99aa21c4a2a268e720db563a1c7f11c0);
#
#
#             var popup_75df157715c9620da526f4eef7020f18 = L.popup({maxWidth: &#x27;200&#x27;
#
#             });
#
#
#                 var html_214a37f0b068ebe0463d92ad8ee4ec89 = $(`&lt;div id=&quot;html_214a37f0b068ebe0463d92ad8ee4ec89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울지방경찰청&lt;/div&gt;`)[0];
#                 popup_75df157715c9620da526f4eef7020f18.setContent(html_214a37f0b068ebe0463d92ad8ee4ec89);
#
#
#             marker_a5e0e2f4e49d394cffc5861eec723605.bindPopup(popup_75df157715c9620da526f4eef7020f18)
#             ;
#
#
#
#
#         var marker_c4fb41842c018a72256d14d3069b03ee = L.marker(
#             [37.57617987638928, 126.97694467807803],
#             {
#                 icon: new L.Icon.Default(),
#                 }
#             ).addTo(map_5da13c41ed701c1aa6b418631350fdb2);
#
#
#
#                 var icon_291bfacd2725307ef74415e9b3d08b63 = L.AwesomeMarkers.icon({
#                     icon: &#x27;hand-down&#x27;,
#                     iconColor: &#x27;white&#x27;,
#                     markerColor: &#x27;orange&#x27;,
#                     prefix: &#x27;glyphicon&#x27;,

# %%
# CircleMarker() : 원 모양의 마커를 생성

map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=16)

popup = folium.Popup('서울특별시청', max_width=200)
folium.CircleMarker(location=[37.56652479270633, 126.9779129116262], popup=popup, radius=100, color='#12A57A', fill_color='#E558A7' ).add_to(map_folium)

map_folium.save('./map.html')
map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_137b09c161d3c8e2e4fce71d26592bb0 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_137b09c161d3c8e2e4fce71d26592bb0&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_137b09c161d3c8e2e4fce71d26592bb0 = L.map(
#         &#x27;map_137b09c161d3c8e2e4fce71d26592bb0&#x27;, {
#         center: [37.56652479270633, 126.9779129116262],
#         zoom: 16,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_e73fcef52b47150bef4acf94f6e6556f = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_137b09c161d3c8e2e4fce71d26592bb0);
#
#             var circle_marker_cec25b133fc731edbc58ea009a11a283 = L.circleMarker(
#                 [37.56652479270633, 126.9779129116262],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#12A57A&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#E558A7&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 100,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_137b09c161d3c8e2e4fce71d26592bb0);
#
#
#             var popup_8ea8b0e2ce1b41306797dd914f8b9129 = L.popup({maxWidth: &#x27;200&#x27;
#
#             });
#
#
#                 var html_7c888393848a24f2f9bb97a1747cd7b0 = $(`&lt;div id=&quot;html_7c888393848a24f2f9bb97a1747cd7b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_8ea8b0e2ce1b41306797dd914f8b9129.setContent(html_7c888393848a24f2f9bb97a1747cd7b0);
#
#
#             circle_marker_cec25b133fc731edbc58ea009a11a283.bindPopup(popup_8ea8b0e2ce1b41306797dd914f8b9129)
#             ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
