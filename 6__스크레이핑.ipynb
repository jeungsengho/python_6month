# %% [markdown]
# <a href="https://colab.research.google.com/github/jeungsengho/python0610/blob/main/6__%EC%8A%A4%ED%81%AC%EB%A0%88%EC%9D%B4%ED%95%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 스크레이핑(Scraping)**

# %% [markdown]
# * 크롤링(Crawling): 인터넷의 데이터를 활용하기 위해 정보들을 분석하고 활용할 수 있게 수집하는 행위
# * 크롤링과 같은 개념이지만 데이터를 추출해서 가공하는 최종 목표

# %% [markdown]
# # **2. 크롤링**

# %% [markdown]
# ### **2-1. basicenglishspeaking.com**

# %%
import requests # 서버에 접속해서 html 문서를 가져오는 역할 (요청 -> 응답)
from bs4 import BeautifulSoup # html 문서를 해석하는 역할 (파싱)

# %%
site = 'https://basicenglishspeaking.com/daily-english-conversation-topics/'
request = requests.get(site)
print(request)  # <Response [200]> 정상적인 접속
# print(request.text) # html
html = request.text
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(html)

# %%
divs = soup.findAll('div', {'class':'thrv-columns'})
print(divs)
# Out:
# [<div class="thrv_wrapper thrv-columns" style="--tcb-col-el-width:792;"><div class="tcb-flex-row tcb--cols--3"><div class="tcb-flex-col"><div class="tcb-col"><div class="thrv_wrapper thrv_text_element"><p>1. <a class="tve-froala" href="https://basicenglishspeaking.com/family/" style="outline: none;">Family</a><br/>2. <a class="tve-froala" href="https://basicenglishspeaking.com/restaurant/" style="outline: none;">Restaurant</a><br/>3. <a href="https://basicenglishspeaking.com/books/">Books</a><br/>4. <a href="https://basicenglishspeaking.com/travel/">Travel</a><br/>5. <a href="https://basicenglishspeaking.com/website/">Website</a><br/>6. <a href="https://basicenglishspeaking.com/accident/">Accident</a><br/>7. <a class="tve-froala" href="https://basicenglishspeaking.com/childhood-memory/" style="outline: none;">Childhood memory</a><br/>8. <a class="tve-froala" href="https://basicenglishspeaking.com/favorite-rooms/" style="outline: none;">Favorite rooms</a><br/>9. <a href="https://basicenglishspeaking.com/presents/">Presents</a><br/>10. <a class="tve-froala" href="https://basicenglishspeaking.com/historical-place/" style="outline: none;">Historical place</a><br/>11. <a class="tve-froala" href="https://basicenglishspeaking.com/newspaper-magazine/" style="outline: none;">Newspaper/ Magazine</a><br/>12. <a href="https://basicenglishspeaking.com/an-event/">A memorable event</a><br/>13. <a href="https://basicenglishspeaking.com/a-subject/">A favorite subject</a><br/>14. <a href="https://basicenglishspeaking.com/a-museum/">A museum</a><br/>15. <a href="https://basicenglishspeaking.com/a-movie/">A favorite movie</a><br/>16. <a href="https://basicenglishspeaking.com/a-foreign-country/">A foreign country</a><br/>17. <a href="https://basicenglishspeaking.com/parties/">Parties</a><br/>18. <a href="https://basicenglishspeaking.com/a-teacher/">A teacher</a><br/>19. <a href="https://basicenglishspeaking.com/a-friend/">A friend</a><br/>20. <a href="https://basicenglishspeaking.com/a-hotel/">A hotel</a><br/>21. <a href="https://basicenglishspeaking.com/a-letter/">A letter</a><br/>22. <a href="https://basicenglishspeaking.com/hobbies/">Hobbies</a><br/>23. <a href="https://basicenglishspeaking.com/music/">Music</a><br/>24. <a href="https://basicenglishspeaking.com/shopping/">Shopping</a><br/>25. <a href="https://basicenglishspeaking.com/holiday/">Holiday</a></p></div></div></div><div class="tcb-flex-col"><div class="tcb-col"><div class="thrv_wrapper thrv_text_element"><p>26. <a class="tve-froala" href="https://basicenglishspeaking.com/animals/" style="outline: none;">Animals</a><br/>27. <a class="tve-froala" href="https://basicenglishspeaking.com/a-practical-skill/" style="outline: none;">A practical skill</a><br/>28. <a href="https://basicenglishspeaking.com/sports/">Sport</a><br/>29. <a href="https://basicenglishspeaking.com/a-school/">A School</a><br/>30. <a href="https://basicenglishspeaking.com/festival/">Festival</a><br/>31. <a href="https://basicenglishspeaking.com/food/">Food</a><br/>32. <a href="https://basicenglishspeaking.com/household-appliance/">Household appliance</a><br/>33. <a href="https://basicenglishspeaking.com/a-music-band/">A music band</a><br/>34. <a href="https://basicenglishspeaking.com/weather/">Weather</a><br/>35. <a href="https://basicenglishspeaking.com/neighbor/">Neighbor</a><br/>36. <a href="https://basicenglishspeaking.com/natural-scenery/">Natural scenery</a><br/>37. <a href="https://basicenglishspeaking.com/outdoor-activities/">Outdoor activities</a><br/>38. <a href="https://basicenglishspeaking.com/law/">Law</a><br/>39. <a href="https://basicenglishspeaking.com/pollution/">Pollution</a><br/>40. <a href="https://basicenglishspeaking.com/traffic-jam/">Traffic jam</a><br/>41. <a href="https://basicenglishspeaking.com/tv-program/">TV program</a><br/>42. <a href="https://basicenglishspeaking.com/architecture-building/">Architect/ Building</a><br/>43. <a href="https://basicenglishspeaking.com/electronic-media/">Electro ...

# %%
subject = []

for div in divs:
  links = div.findAll('a')
  # print(links)
  for link in links:
   # print(link.text)
   subject.append(link.text)

# %%
print('총', len(subject), '개의 주제를 찾았습니다.')
for i in range(len(subject)):
  print('{0:2d}. {1:s}'.format(i+1, subject[i]))
# Out:
# 총 75 개의 주제를 찾았습니다.
#  1. Family
#  2. Restaurant
#  3. Books
#  4. Travel
#  5. Website
#  6. Accident
#  7. Childhood memory
#  8. Favorite rooms
#  9. Presents
# 10. Historical place
# 11. Newspaper/ Magazine
# 12. A memorable event
# 13. A favorite subject
# 14. A museum
# 15. A favorite movie
# 16. A foreign country
# 17. Parties
# 18. A teacher
# 19. A friend
# 20. A hotel
# 21. A letter
# 22. Hobbies
# 23. Music
# 24. Shopping
# 25. Holiday
# 26. Animals
# 27. A practical skill
# 28. Sport
# 29. A School
# 30. Festival
# 31. Food
# 32. Household appliance
# 33. A music band
# 34. Weather
# 35. Neighbor
# 36. Natural scenery
# 37. Outdoor activities
# 38. Law
# 39. Pollution
# 40. Traffic jam
# 41. TV program
# 42. Architect/ Building
# 43. Electronic Media
# 44. Job/ Career
# 45. Competition/ contest
# 46. A garden
# 47. Hometown
# 48. Clothing
# 49. Advertisement
# 50. A project
# 51. A wedding
# 52. A Coffee shop
# 53. Culture
# 54. Transport
# 55. Politician
# 56. Communication
# 57. Business
# 58. Computer
# 59. Exercise
# 60. Goal/ ambition
# 61. Art
# 62. Fashion
# 63. Jewelry
# 64. Cosmetic
# 65. Indoor Game
# 66. Phone conversation
# 67. Learning A Second language
# 68. A Creative Person
# 69. A celebrity
# 70. A Health Problem
# 71. Technological advancements
# 72. A Landmark
# 73. Handcraft Items
# 74. Plastic Surgery
# 75. Success

# %% [markdown]
# ### **2-2. 다음 뉴스기사**

# %%
# https://movie.v.daum.net/v/20220625085027862

def daum_news_title(news_id):
  # url = 'https://movie.v.daum.net/v/{}'+ news_id
  url = 'https://movie.v.daum.net/v/{}'.format(news_id)
  request = requests.get(url)
  # print(request)
  soup = BeautifulSoup(request.text)
  # title = soup.findAll('h3', {'class':'tit_view'})
  # title = soup.find('h3', {'class':'tit_view'})
  title = soup.select_one('h3.tit_view')
  if title:
    return title.text.strip()
  return ''

# %%
daum_news_title('20220625085027862')
# Out:
# '팬데믹 후 첫 천만..마동석 펀치로 심폐소생한 극장가 [상반기 결산-영화]'

# %%
daum_news_title('20220625093301536')
# Out:
# '누구라도 외면하고 싶은 금기에 도전하는 이 영화'

# %%
daum_news_title('20220627174244810')
# Out:
# '수지에게 결혼·유학 제안했던 그 남자..허형규 "\'안나\' 참여 영광"'

# %% [markdown]
# ### **2-3. 벅스뮤직 차트**

# %%
request = requests.get('https://music.bugs.co.kr/chart')
html = request.text
soup = BeautifulSoup(html)

titles = soup.findAll('p',{'class':'title'})
# print(titles)

artists = soup.findAll('p',{'class':'artist'})
# print(artists)

# %%
for i in range(len(titles)):
  title = titles[i].text.strip()
  artist = artists[i].text.strip().split('\n')[0] # split('\n') -> '\n' 을 기준으로 나누어서 앞에 0번째만 저장
  data = '{0:3d}위 {1} - {2}'.format(i+1, artist, title)
  print(data)
# Out:
#   1위 이민혁 (HUTA) - BOOM
#   2위 프로미스나인 - Stay This Way
#   3위 프로미스나인 - Rewind
#   4위 프로미스나인 - Blind Letter
#   5위 프로미스나인 - Cheese
#   6위 프로미스나인 - Up And
#   7위 이민혁 (HUTA) - 그대가 모르게
#   8위 이민혁 (HUTA) - 사랑일까요 (Duet. 이창섭 of 비투비)
#   9위 이민혁 (HUTA) - 넌 나의 봄이야
#  10위 이민혁 (HUTA) - Shadow
#  11위 나연 (TWICE) - POP!
#  12위 IVE (아이브) - LOVE DIVE
#  13위 Charlie Puth(찰리 푸스) - Left and Right (Feat. Jung Kook of BTS)
#  14위 이무진 - 참고사항
#  15위 (여자)아이들 - TOMBOY
#  16위 LE SSERAFIM (르세라핌) - FEARLESS
#  17위 BIG Naughty (서동현) - 정이라고 하자 (Feat. 10CM)
#  18위 aespa - Life′s Too Short (English Ver.)
#  19위 싸이 (PSY) - That That (prod. & feat. SUGA of BTS)
#  20위 다비치 - 팡파레
#  21위 방탄소년단 - Yet To Come
#  22위 멜로망스(MeloMance) - 사랑인가 봐
#  23위 aespa - 도깨비불 (Illusion)
#  24위 케이시 - 늦은 밤 헤어지긴 너무 아쉬워
#  25위 Red Velvet (레드벨벳) - Feel My Rhythm
#  26위 Charlie Puth(찰리 푸스) - That's Hilarious
#  27위 경서 - 나의 X에게
#  28위 IVE (아이브) - ELEVEN
#  29위 이민혁 (HUTA) - I’m Rare
#  30위 이민혁 (HUTA) - Real Game (Like Messi)
#  31위 폴킴(Paul Kim) - One More Time
#  32위 이민혁 (HUTA) - Red Wine
#  33위 BE'O (비오) - LOVE me
#  34위 이민혁 (HUTA) - 우리 함께 걸어요
#  35위 이민혁 (HUTA) - 위험해
#  36위 이민혁 (HUTA) - 끝 눈
#  37위 BIGBANG (빅뱅) - 봄여름가을겨울 (Still Life)
#  38위 조유리 - 러브 쉿!
#  39위 (여자)아이들 - MY BAG
#  40위 주시크 (Joosiq) - 아무래도 난
#  41위 이민혁 (HUTA) - 기다리고 있어
#  42위 The Kid LAROI - STAY
#  43위 태연 (TAEYEON) - INVU
#  44위 이무진 - 신호등
#  45위 10CM - 봄 to 러브
#  46위 BIG Naughty (서동현) - 낭만교향곡 (Feat. CHANGMO, 박재범)
#  47위 aespa - Next Level
#  48위 경서예지 - 다정히 내 이름을 부르면
#  49위 아이유(IU) - 드라마
#  50위 박재범 - GANADARA (Feat. 아이유)
#  51위 김민석 (멜로망스) - 취중고백
#  52위 YENA (최예나) - SMILEY (Feat. BIBI)
#  53위 WSG워너비 - 어마어마해
#  54위 임재현 - 고백하는 취한밤에 (Prod. 2soo)
#  55위 볼빨간사춘기 - Seoul
#  56위 (여자)아이들 - 말리지 마
#  57위 잔나비 - 초록을거머쥔우리는
#  58위 멜로망스(MeloMance) - Happy Song
#  59위 정승환 - 흔한 거짓말
#  60위 헤이즈(Heize) - 마지막 너의 인사
#  61위 아이유(IU) - strawberry moon
#  62위 이달의 소녀 - Flip That
#  63위 태연 (TAEYEON) - Weekend
#  64위 MSG워너비(M.O.M) - 듣고 싶을까
#  65위 세븐틴(SEVENTEEN) - HOT
#  66위 제시(Jessi) - ZOOM
#  67위 NCT DREAM - Beatbox
#  68위 볼빨간사춘기 - Love story
#  69위 임영웅 - 우리들의 블루스
#  70위 김희재 - 짠짠짠
#  71위 미연 ((여자)아이들) - Drive
#  72위 성시경 - 너의 모든 순간
#  73위 방탄소년단 - Dynamite
#  74위 Charlie Puth(찰리 푸스) - Light Switch
#  75위 임영웅 - 사랑은 늘 도망가
#  76위 쿠기 (Coogie) - Alone (Feat. 이하이)
#  77위 Justin Bieber(저스틴 비버) - Off My Face
#  78위 싸이 (PSY) - 감동이야 (feat. 성시경)
#  79위 아이유(IU) - Celebrity
#  80위 Lauv(라우브) - All 4 Nothing (I'm So In Love)
#  81위 멜로망스(MeloMance) - 초대
#  82위 Harry Styles(해리 스타일스) - As It Was
#  83위 싸이 (PSY) - Celeb
#  84위 WSG워너비 조별경연 (대청봉) - YOU AND I
#  85위 백예린 (Yerin Baek) - 물고기
#  86위 방탄소년단 - Butter
#  87위 김희재 - 풍악
#  88위 sokodomo - 회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
#  89위 이효리 - FREE SMILE
#  90위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  91위 주호 - 내가 아니라도
#  92위 아이유(IU) - Blueming
#  93위 주시크 (Joosiq) - 너를 생각해
#  94위 아이유(IU) - 라일락
#  95위 프로미스나인 - DM
#  96위 STAYC(스테이씨) - RUN2U
#  97위 방탄소년단 - Permission to Dance
#  98위 세븐틴(SEVENTEEN) - Darl+ing
#  99위 태연 (TAEYEON) - 내 곁에
# 100위 윤하(Younha/ユンナ) - 사건의 지평선

# %% [markdown]
# ### **2-4. 멜론 차트**

# %%
url = 'https://www.melon.com/chart/index.htm'
request = requests.get(url)
print(request)
# Out:
# <Response [406]>

# %%
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36
header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
url = 'https://www.melon.com/chart/index.htm'
request = requests.get(url, headers=header)
print(request)
# Out:
# <Response [200]>

# %%
html = request.text
soup = BeautifulSoup(html)

titles = soup.findAll('div',{'class':'rank01'})
# print(titles)

artists = soup.findAll('span',{'class':'checkEllipsis'})
print(artists)
# Out:
# [<span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2137482');" title="(여자)아이들 - 페이지 이동">(여자)아이들</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3865');" title="싸이 (PSY) - 페이지 이동">싸이 (PSY)</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2744750');" title="BIG Naughty (서동현) - 페이지 이동">BIG Naughty (서동현)</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994005');" title="경서 - 페이지 이동">경서</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('198094');" title="BIGBANG (빅뱅) - 페이지 이동">BIGBANG (빅뱅)</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3092950');" title="LE SSERAFIM (르세라핌) - 페이지 이동">LE SSERAFIM (르세라핌)</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2758756');" title="BE'O (비오) - 페이지 이동">BE'O (비오)</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('839736');" title="김민석 (멜로망스) - 페이지 이동">김민석 (멜로망스)</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('838654');" title="Charlie Puth - 페이지 이동">Charlie Puth</a>, <a href="javascript:melon.link.goArtistDetail('725987');" title="정국 - 페이지 이동">정국</a>, <a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('683631');" title="주호 - 페이지 이동">주호</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2138620');" title="이무진 - 페이지 이동">이무진</a></span>, <span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>, <span class="checkEl ...

# %%
for i in range(len(titles)):
  title = titles[i].text.strip()
  artist = artists[i].text.strip()
  data = '{0:3d}위 {1} - {2}'.format(i+1, artist, title)
  # data = (f'{i+1}위 {artist} - {title}')
  print(data)
# Out:
#   1위 IVE (아이브) - LOVE DIVE
#   2위 (여자)아이들 - TOMBOY
#   3위 싸이 (PSY) - That That (prod. & feat. SUGA of BTS)
#   4위 멜로망스 - 사랑인가 봐
#   5위 임영웅 - 우리들의 블루스
#   6위 BIG Naughty (서동현) - 정이라고 하자 (Feat. 10CM)
#   7위 임영웅 - 사랑은 늘 도망가
#   8위 경서 - 나의 X에게
#   9위 임영웅 - 다시 만날 수 있을까
#  10위 방탄소년단 - Yet To Come
#  11위 BIGBANG (빅뱅) - 봄여름가을겨울 (Still Life)
#  12위 LE SSERAFIM (르세라핌) - FEARLESS
#  13위 BE'O (비오) - LOVE me
#  14위 임영웅 - 무지개
#  15위 김민석 (멜로망스) - 취중고백
#  16위 Red Velvet (레드벨벳) - Feel My Rhythm
#  17위 Charlie Puth, 정국, 방탄소년단 - Left and Right (Feat. Jung Kook of BTS)
#  18위 임영웅 - 이제 나만 믿어요
#  19위 주호 - 내가 아니라도
#  20위 임영웅 - 아버지
#  21위 IVE (아이브) - ELEVEN
#  22위 방탄소년단 - Dynamite
#  23위 임영웅 - 손이 참 곱던 그대
#  24위 이무진 - 신호등
#  25위 임영웅 - A bientot
#  26위 임영웅 - 사랑해 진짜
#  27위 경서예지, 전건호 - 다정히 내 이름을 부르면
#  28위 방탄소년단 - Butter
#  29위 임영웅 - 인생찬가
#  30위 주시크 (Joosiq) - 아무래도 난
#  31위 임영웅 - 연애편지
#  32위 박재범 - GANADARA (Feat. 아이유)
#  33위 임영웅 - 사랑역
#  34위 (여자)아이들 - MY BAG
#  35위 방탄소년단 - Permission to Dance
#  36위 케이시 (Kassy) - 늦은 밤 헤어지긴 너무 아쉬워
#  37위 임영웅 - 보금자리
#  38위 The Kid LAROI, Justin Bieber - STAY
#  39위 태연 (TAEYEON) - INVU
#  40위 임영웅 - 사랑해요 그대를
#  41위 Charlie Puth - That's Hilarious
#  42위 MSG워너비(M.O.M) - 듣고 싶을까
#  43위 임재현 - 고백하는 취한밤에 (Prod. 2soo)
#  44위 성시경 - 너의 모든 순간
#  45위 제시 (Jessi) - ZOOM
#  46위 나연 (TWICE) - POP!
#  47위 YENA (최예나) - SMILEY (Feat. BIBI)
#  48위 태연 (TAEYEON) - Weekend
#  49위 aespa - Next Level
#  50위 방탄소년단 - 봄날
#  51위 주시크 (Joosiq) - 너를 생각해
#  52위 세븐틴 - HOT
#  53위 다비치 - 팡파레
#  54위 Coldplay, 방탄소년단 - My Universe
#  55위 sokodomo - 회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
#  56위 아이유 - 내 손을 잡아
#  57위 케이시 (Kassy) - 언제나 사랑해
#  58위 아이유 - 드라마
#  59위 BIG Naughty (서동현) - 낭만교향곡 (Feat. CHANGMO, 박재범)
#  60위 방탄소년단 - Born Singer
#  61위 BE'O (비오) - 리무진 (Feat. MINO) (Prod. GRAY)
#  62위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  63위 아이유 - strawberry moon
#  64위 디핵 (D-Hack), PATEKO (파테코) - OHAYO MY NIGHT
#  65위 지민, 하성운 - With you
#  66위 MSG워너비(M.O.M) - 바라만 본다
#  67위 방탄소년단 - 달려라 방탄
#  68위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  69위 자우림 - 스물다섯, 스물하나
#  70위 경서 - 밤하늘의 별을(2020)
#  71위 STAYC(스테이씨) - RUN2U
#  72위 이무진 - 눈이 오잖아(Feat.헤이즈)
#  73위 방탄소년단 - For Youth
#  74위 Justin Bieber - Off My Face
#  75위 NCT DREAM - Beatbox
#  76위 아이유 - 라일락
#  77위 아이유 - Celebrity
#  78위 aespa - Savage
#  79위 멜로망스 - 고백
#  80위 탑현 - 호랑수월가
#  81위 브레이브걸스 - 롤린 (Rollin')
#  82위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
#  83위 아이유 - Blueming
#  84위 세븐틴 - Darl+ing
#  85위 V.O.S - 미친 것처럼
#  86위 BE'O (비오) - 문득
#  87위 마크툽 (MAKTUB) - 찰나가 영원이 될 때 (The Eternal Moment)
#  88위 Ed Sheeran - Bad Habits
#  89위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  90위 주호 - 그 하루(feat.반하나)
#  91위 BE'O (비오) - Counting Stars (Feat. Beenzino)
#  92위 볼빨간사춘기 - Love story
#  93위 헤이즈 (Heize) - 헤픈 우연
#  94위 오마이걸 (OH MY GIRL) - Dun Dun Dance
#  95위 볼빨간사춘기 - Seoul
#  96위 #안녕 - 해요 (2022)
#  97위 이무진 - 참고사항
#  98위 GOT the beat - Step Back
#  99위 aespa - Life′s Too Short (English Ver.)
# 100위 싸이 (PSY) - Celeb

# %% [markdown]
# **2-4. 지니 차트 200**

# %%
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220627&hh=21&rtm=Y&pg='
for i in range(1,5):
  site = '{}{}'.format(url, i)
  print(site)
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220627&hh=21&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220627&hh=21&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220627&hh=21&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220627&hh=21&rtm=Y&pg=4

# %%
import time

# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36
header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20220627&hh=21&rtm=Y&pg='
for i in range(1,5):
  site = '{}{}'.format(url, i)
  request = requests.get(site, headers=header)
  time.sleep(1)
  soup = BeautifulSoup(request.text)
  
  titles = soup.findAll('a', {'class':'title ellipsis'})
  print(titles)
# Out:
# [<a class="title ellipsis" href="#" onclick="fnPlaySong('96480048','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 LOVE DIVE</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96664100','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 That That (Prod. &amp; Feat. SUGA of BTS)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96276241','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 TOMBOY</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96042335','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 사랑인가 봐</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96613134','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 나의 X에게</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96587489','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 정이라고 하자 (Feat. 10CM)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94535712','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 사랑은 늘 도망가</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96549502','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 우리들의 블루스</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96517321','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 LOVE me</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96482850','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 봄여름가을겨울 (Still Life)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97028103','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Yet To Come</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696680','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 FEARLESS</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696809','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 다시 만날 수 있을까</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95376934','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 취중고백</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93300145','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 신호등</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('90077755','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 이제 나만 믿어요</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96367880','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 내가 아니라도</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96316069','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Feel My Rhythm</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696807','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 무지개</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93336453','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 다정히 내 이름을 부르면</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96276248','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 MY BAG</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696810','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 아버지</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96507978','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 That's Hilarious</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95188110','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 ELEVEN</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696811','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 A bientot</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696808','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 손이 참 곱던 그대</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696814','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 사랑해 진짜</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97183185','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Left and Right (Feat. Jung Kook of BTS)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696812','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 사랑역</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696815','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 연애편지</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96239500','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 GANADARA (Feat. 아이유)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696813','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 보금자리</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93717294','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Stay</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96791165','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 팡파레</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696816','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 사랑해요 그대를</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96696817','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 인생찬가</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96426855','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 아무래도 난</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93352112','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Butter</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96529831','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 ZOOM</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('90705547','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Dynamite</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96109972','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 듣고 싶을까</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95990155','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 INVU</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94932434','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 회전목마 (Feat. Zion.T &amp; 원슈타인) (Prod. by Slom)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97209570','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 POP!</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96830137','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 늦은 밤 헤어지긴 너무 아쉬워</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97255436','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Stay This Way</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93721048','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Permission to Dance</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('82280761','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 너의 모든 순간</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93330349','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Next Level</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('88773173','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)</a>]
# [<a class="title ellipsis" href="#" onclick="fnPlaySong('97019722','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 고백하는 취한밤에 (Prod. by 2soo)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96951358','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 해요 (2022)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96664101','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Celeb</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94395717','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 My Universe</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94314085','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 너를 생각해</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95038278','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 리무진 (Feat. MINO) (Prod. by GRAY)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('90413574','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 OHAYO MY NIGHT</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94054417','1');return false;" title="재생">
# <span class="icon icon-19">19<span class="hide">금</span></span>
#
#
#
#
#                                                 abcdefu</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93616612','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Bad Habits</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93700014','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Weekend</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('82072538','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 스물다섯, 스물하나</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('81230210','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Stronger (What Doesn't Kill You)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96899921','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 HOT</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95684421','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 호랑수월가</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94653222','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 strawberry moon</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93619160','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 바라만 본다</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93340450','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Every Second</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95927624','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 언제나 사랑해</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97196776','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 참고사항</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96988596','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 그 하루 (Feat. 반하나)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93154148','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 문득</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('87840106','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 모든 날, 모든 순간 (Every day, Every Moment)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94133414','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 고백</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('81018403','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 내 손을 잡아</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('87928158','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 2002</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('92125854','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Celebrity</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95683977','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 SMILEY (Feat. BIBI)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95299676','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Counting Stars (Feat. Beenzino)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93299407','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Loving You Girl (Feat. Hkeem)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('92797995','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Tiny Riot</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('86941521','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 봄날</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('92749701','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 라일락</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94321284','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 찰나가 영원이 될 때 (The Eternal Moment)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('90539282','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Rainy day (Feat. ASH ISLAND &amp; Skinny Brown)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('91361957','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 밤하늘의 별을 (2020)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('89382909','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93335952','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 헤픈 우연</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('92673418','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 사이렌 Remix (Feat. UNEDUCATED KID &amp; Paul Blanco)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95514753','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 드라마</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('89058209','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96664102','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 감동이야 (Feat. 성시경)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96606859','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 With you</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('90788463','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 만개 (Prod. 신지후)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96791346','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 미친 것처럼</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('89613039','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Blueming</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('90544866','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 At My Worst</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('92682935','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Off My Face</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('89320910','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('90160784','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 나보다 더 사랑해요</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('86992414','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 롤린 (Rollin')</a>]
# [<a class="title ellipsis" href="#" onclick="fnPlaySong('92156075','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 추억은 만남보다 이별에 남아</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97223303','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Alone (Feat. 이하이)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97028085','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Born Singer</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('81461935','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 오래된 노래</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95256356','1');return false;" title="재생">
#
#
#
# ...
#
#
#
#
#
#
#                                                 마지막 너의 인사</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('89296790','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 안녕</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('89943155','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 어떻게 지내 (Prod. by VAN.C)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('87034188','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 밤편지</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('91623162','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 여자의 마음 (La Donna E Mobile)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97208727','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Life's Too Short (English Ver.)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96891708','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 러브 쉿!</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('91359951','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 parachute</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('86868163','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Shape Of You</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('82779996','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 사랑하긴 했었나요 스쳐가는 인연이었나요 짧지않은 우리 함께했던 시간들이 자꾸 내 마음을 가둬두네</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('81397683','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 어땠을까 (Feat. 박정현)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96786054','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Happy Song</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('89815269','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 시작</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('90545014','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 취기를 빌려 (취향저격 그녀 X 산들)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96276242','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 말리지 마</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('89859975','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 마음을 드려요</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95300168','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 우리가 헤어져야 했던 이유</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97209781','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 비가 오는 밤이면</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('92911541','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 ASAP</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('86014550','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 이 사랑</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('97223297','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 자장가</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('92749708','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 어푸 (Ah puh)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95514755','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 겨울잠</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('82637237','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 한여름밤의 꿀</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('95422584','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Dreams Come True</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('96104471','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 존재만으로</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('16151403','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 희재</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('60135596','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 우산 (Feat. 윤하)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94844692','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 쉬어 (Feat. MINO) (Prod. by GRAY)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('91066986','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Ashes</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('87240368','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 비도 오고 그래서 (Feat. 신용재)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94844691','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Wake Up (Prod. by 코드 쿤스트)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('93569588','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 비 오는 날 듣기 좋은 노래 (Feat. Colde)</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('88281290','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Paris In The Rain</a>, <a class="title ellipsis" href="#" onclick="fnPlaySong('94020692','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Queendom</a>]
